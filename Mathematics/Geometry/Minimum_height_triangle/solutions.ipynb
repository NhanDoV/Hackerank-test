# %% [markdown]
# # Introduction
# [Reference](https://www.hackerrank.com/challenges/lowest-triangle/problem?isFullScreen=true)
#
# Given integers $b$ and $a$, find the smallest integer $h$, such that there exists a triangle of height $h$, base $b$, having an area of at least $a$.
#
# #### Example
# The minimum height $h$ is $3$. One example is a triangle formed at points $(0, 0), (4, 0), (2, 3)$.
#
# #### Function Description
# Complete the `lowestTriangle` function, the `lowestTriangle`` has the following parameters:
#
# - int b: the base of the triangle
# - int a: the minimum area of the triangle
#
# Returns
#
# - int: the minimum integer height to form a triangle with an area of at least
#
# Input Format
# - There are two space-separated integers $b$ and $a$, on a single line.

# %%
import math
import matplotlib.pyplot as plt

def lowestTriangle(trianglebase, area):
    # Write your code here
    return math.ceil(2*area / trianglebase)

# %% [markdown]
# ### Test-case 1.

# %%
triangle_coordinates = [(0, 0), (4, 0), (2, 3), (0, 0)]
plt.figure(figsize=(5, 5))
plt.plot([d[0] for d in triangle_coordinates], [d[1] for d in triangle_coordinates])
plt.plot([2, 2], [3, 0], 'green', alpha=0.5)
for x, y in triangle_coordinates:
    plt.plot(x, y, 'o', color='red')
plt.title(f"Base: 4, area: 6 and height: {lowestTriangle(4, 6)}")
plt.text(2.05, 0.05, 'base', color='red')
plt.text(2.05, 1.5, 'height', color='blue')
plt.show()

# %% [markdown]
# ### Test-case 2

# %%
triangle_coordinates = [(2, 2), (19, 2), (16, 4), (2, 2)]
plt.figure(figsize=(15, 5))
plt.plot([d[0] for d in triangle_coordinates], [d[1] for d in triangle_coordinates])
plt.plot([16, 16], [4, 2], 'green', alpha=0.5)
for x, y in triangle_coordinates:
    plt.plot(x, y, 'o', color='red')
plt.title(f"Base: 17, area: 100 and height: {lowestTriangle(17, 100)}")
plt.text(16.05, 2.05, 'base', color='red')
plt.text(16.05, 3.25, 'height', color='blue')
plt.show()
